# %%
import torch
import torch.nn as nn    # 激励函数都在这
from torch.autograd import Variable
import matplotlib.pyplot as plt

# %%
x = torch.linspace(-6,6,500) 
x = Variable(x)

# %%
x_np = x.data.numpy() # 换成 numpy array, 用于画图

# %%
y_relu = nn.functional.relu(x).data.numpy()
y_sigmoid = nn.functional.sigmoid(x).data.numpy()
y_tanh = nn.functional.tanh(x).data.numpy()
y_softplus = nn.functional.softplus(x).data.numpy()
# Out:
# /home/neu/anaconda3/envs/pytorch-env/lib/python3.6/site-packages/torch/nn/functional.py:1628: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %%
y_relu = torch.relu(x).data.numpy()
y_sigmoid = torch.sigmoid(x).data.numpy()
y_tanh = torch.tanh(x).data.numpy()
y_softplus = nn.Softplus()(x).data.numpy()

# %%
plt.figure(1,figsize=(8,6))

plt.subplot(221)
plt.plot(x_np,y_relu,c='red',label='relu')
plt.ylim((-1, 5))
plt.legend(loc='best')

plt.subplot(222)
plt.plot(x_np,y_tanh,c='red',label='tanh')
plt.ylim((-1.2, 1.2))
plt.legend(loc='best')

plt.subplot(223)
plt.plot(x_np,y_sigmoid,c='red',label='sigmoid')
plt.ylim((-0.2, 1.2))
plt.legend(loc='best')

plt.subplot(224)
plt.plot(x_np,y_softplus,c='red',label='softplus')
plt.ylim((-0.2, 6))
plt.legend(loc='best')

plt.show()
